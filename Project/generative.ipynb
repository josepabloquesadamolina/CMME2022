# %% [markdown]
# # Import initialization packages

# %%
from pyimagesearch import datasets
import locale
import os
from tensorflow.python.client import device_lib
import tensorflow as tf

# Save the working directory path in the variable "inputPath" 
inputPath = os.getcwd()
os.chdir(inputPath)
print(inputPath)
# Out:
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022

# %% [markdown]
# # Verify CPU or GPU availability

# %%
print(tf.config.list_physical_devices('GPU'))
print(device_lib.list_local_devices())
# Out:
# []
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 642012412393245631
# xla_global_id: -1
# ]

# %% [markdown]
# #  Load the images and labels

# %%
res=64 # The resolution of images can be adjusted as required

#-----------------------------------------------------8000 RVES 2x2 LABELS------------------------------

df1=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\1k',[2])
df2=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\2k',[2])
df3=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\3k',[2])
df4=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\4k',[2])
df5=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\5k',[2])
df6=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\6k',[2])
df7=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\7k',[2])
df8=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_2x2\\8k',[2])


print('Adding 1k')
original_labels_2x2_8000=[]
for i in range(0,989):
	original_labels_2x2_8000.append(df1.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 2k')
for i in range(0,963):
	original_labels_2x2_8000.append(df2.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 3k')
for i in range(0,953):
	original_labels_2x2_8000.append(df3.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 4k')
for i in range(0,973):
	original_labels_2x2_8000.append(df4.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 5k')
for i in range(0,980):
	original_labels_2x2_8000.append(df5.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 6k')
for i in range(0,970):
	original_labels_2x2_8000.append(df6.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 7k')
for i in range(0,978):
	original_labels_2x2_8000.append(df7.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))

print('Adding 8k')
for i in range(0,966):
	original_labels_2x2_8000.append(df8.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_2x2_8000))



#--------------------------------------------------------------2X2 8000 IMAGES-------------------------------------

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\1k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_1k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_1k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\2k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_2k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_2k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\3k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_3k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_3k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\4k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_4k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_4k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\5k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_5k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_5k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\6k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_6k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_6k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\7k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_7k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_7k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_2x2\\8k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 2x2 RVE images
print("[INFO] loading original 2x2_8000 RVE images...")
original_images_2x2_8k = datasets.load_RVE_original_images(inputPathtemp,[2],res,999)
print(original_images_2x2_8k.shape)



#-----------------------------------------------------////////////////////------------------------------
#-----------------------------------------------------4000 RVES 5x5 LABELS------------------------------

df9=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_5x5\\1k',[5])
df10=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_5x5\\2k',[5])
df11=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_5x5\\3k',[5])
df12=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_5x5\\4k',[5])


print('Adding 1k')
original_labels_5x5_4000=[]
for i in range(0,969):
	original_labels_5x5_4000.append(df9.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_5x5_4000))

print('Adding 2k')
for i in range(0,962):
	original_labels_5x5_4000.append(df10.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_5x5_4000))

print('Adding 3k')
for i in range(0,964):
	original_labels_5x5_4000.append(df11.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_5x5_4000))

print('Adding 4k')
for i in range(0,959):
	original_labels_5x5_4000.append(df12.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_5x5_4000))



#--------------------------------------------------------------5x5 4000 IMAGES-------------------------------------

inputPathtemp = inputPath+'\\Data\\Generated_Images_5x5\\1k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 5x5 RVE images
print("[INFO] loading original 5x5_8000 RVE images...")
original_images_5x5_1k = datasets.load_RVE_original_images(inputPathtemp,[5],res,999)
print(original_images_5x5_1k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_5x5\\2k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 5x5 RVE images
print("[INFO] loading original 5x5_4000 RVE images...")
original_images_5x5_2k = datasets.load_RVE_original_images(inputPathtemp,[5],res,999)
print(original_images_5x5_2k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_5x5\\3k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 5x5 RVE images
print("[INFO] loading original 5x5_4000 RVE images...")
original_images_5x5_3k = datasets.load_RVE_original_images(inputPathtemp,[5],res,999)
print(original_images_5x5_3k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_5x5\\4k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 5x5 RVE images
print("[INFO] loading original 5x5_4000 RVE images...")
original_images_5x5_4k = datasets.load_RVE_original_images(inputPathtemp,[5],res,999)
print(original_images_5x5_4k.shape)

#-----------------------------------------------------//////////////////////------------------------------
#-----------------------------------------------------4000 RVES 10x10 LABELS------------------------------

df13=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_10x10\\1k',[10])
df14=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_10x10\\2k',[10])
df15=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_10x10\\3k',[10])
df16=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_10x10\\4k',[10])



print('Adding 1k')
original_labels_10x10_4000=[]
for i in range(0,956):
	original_labels_10x10_4000.append(df13.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_10x10_4000))

print('Adding 2k')
for i in range(0,953):
	original_labels_10x10_4000.append(df14.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_10x10_4000))

print('Adding 3k')
for i in range(0,948):
	original_labels_10x10_4000.append(df15.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_10x10_4000))

print('Adding 4k')
for i in range(0,960):
	original_labels_10x10_4000.append(df16.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_10x10_4000))



#--------------------------------------------------------------10x10 4000 IMAGES-------------------------------------

inputPathtemp = inputPath+'\\Data\\Generated_Images_10x10\\1k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 10x10 RVE images
print("[INFO] loading original 10x10_4000 RVE images...")
original_images_10x10_1k = datasets.load_RVE_original_images(inputPathtemp,[10],res,999)
print(original_images_10x10_1k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_10x10\\2k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 10x10 RVE images
print("[INFO] loading original 10x10_4000 RVE images...")
original_images_10x10_2k = datasets.load_RVE_original_images(inputPathtemp,[10],res,999)
print(original_images_10x10_2k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_10x10\\3k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 10x10 RVE images
print("[INFO] loading original 10x10_4000 RVE images...")
original_images_10x10_3k = datasets.load_RVE_original_images(inputPathtemp,[10],res,999)
print(original_images_10x10_3k.shape)

inputPathtemp = inputPath+'\\Data\\Generated_Images_10x10\\4k'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 10x10 RVE images
print("[INFO] loading original 10x10_4000 RVE images...")
original_images_10x10_4k = datasets.load_RVE_original_images(inputPathtemp,[10],res,999)
print(original_images_10x10_4k.shape)

#-----------------------------------------------------//////////////////////------------------------------
#-----------------------------------------------------4000 RVES 3x3 LABELS------------------------------

df17=datasets.load_RVE_labels_displ(inputPath+'\\Data\\Generated_Images_3x3',[3])

original_labels_3x3_4000=[]
for i in range(0,3980):
	original_labels_3x3_4000.append(df17.loc[i,"E1_Uniform_Strain_BCs"])
print(len(original_labels_3x3_4000))

inputPathtemp = inputPath+'\\Data\\Generated_Images_3x3'
os.chdir(inputPathtemp)
print(inputPathtemp)

# load the original 10x10 RVE images
print("[INFO] loading original 3x3_4000 RVE images...")
original_images_3x3_4k = datasets.load_RVE_original_images(inputPathtemp,[3],res,4091)
print(original_images_3x3_4k.shape)

os.chdir(inputPath)
# Out:
# Adding 1k
# 989
# Adding 2k
# 1952
# Adding 3k
# 2905
# Adding 4k
# 3878
# Adding 5k
# 4858
# Adding 6k
# 5828
# Adding 7k
# 6806
# Adding 8k
# 7772
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\1k
# [INFO] loading original 2x2_8000 RVE images...
# ...
# (989, 64, 64)
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\2k
# [INFO] loading original 2x2_8000 RVE images...
# ...
# (963, 64, 64)
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\3k
# [INFO] loading original 2x2_8000 RVE images...
# ...
# (953, 64, 64)
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\4k
# [INFO] loading original 2x2_8000 RVE images...
# ...
# (973, 64, 64)
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\5k
# [INFO] loading original 2x2_8000 RVE images...
# ...
# (980, 64, 64)
# D:\Jupyter Notebook Projects\My_Works\t CMME 2022\Data\Generated_Images_2x2\6k
# ...

# %% [markdown]
# # Assemble the dataset

# %%
# SETS and LABELS
print("Assemble Dataset")

#INITIALIZE THE SETS
_2x2_images=np.zeros([7772,res,res]) 
_3x3_images=np.zeros([3980,res,res]) 
_5x5_images=np.zeros([3854,res,res]) 
_10x10_images=np.zeros([3817,res,res]) 

#FILL THE SETS WITH THE IMAGES
_2x2_images[0:989,:,:]=original_images_2x2_1k 
_2x2_images[989:1952,:,:]=original_images_2x2_2k
_2x2_images[1952:2905,:,:]=original_images_2x2_3k
_2x2_images[2905:3878,:,:]=original_images_2x2_4k
_2x2_images[3878:4858,:,:]=original_images_2x2_5k
_2x2_images[4858:5828,:,:]=original_images_2x2_6k
_2x2_images[5828:6806,:,:]=original_images_2x2_7k
_2x2_images[6806:7772,:,:]=original_images_2x2_8k
_2x2_images = np.expand_dims(_2x2_images, -1)


_3x3_images[0:3980,:,:]=original_images_3x3_4k
_3x3_images = np.expand_dims(_3x3_images, -1)

_5x5_images[0:969,:,:]=original_images_5x5_1k
_5x5_images[969:1931,:,:]=original_images_5x5_2k
_5x5_images[1931:2895,:,:]=original_images_5x5_3k
_5x5_images[2895:3854,:,:]=original_images_5x5_4k
_5x5_images = np.expand_dims(_5x5_images, -1)

_10x10_images[0:956,:,:]=original_images_10x10_1k
_10x10_images[956:1909,:,:]=original_images_10x10_2k
_10x10_images[1909:2857,:,:]=original_images_10x10_3k
_10x10_images[2857:3817,:,:]=original_images_10x10_4k
_10x10_images = np.expand_dims(_10x10_images, -1)

print("Dimension of the input data (Images)")
print(_2x2_images.shape)
print(_3x3_images.shape)
print(_5x5_images.shape)
print(_10x10_images.shape)


#LABELS FOR THE IMAGES
_2x2_labels1= np.full(len(original_labels_2x2_8000), 2)
_3x3_labels1=np.full(len(original_labels_3x3_4000), 3)  
_5x5_labels1=np.full(len(original_labels_5x5_4000), 5)
_10x10_labels1= np.full(len(original_labels_10x10_4000), 10)

print("Dimension of label arrays (Categories)")
print(len(_2x2_labels1))
print(len(_3x3_labels1))
print(len(_5x5_labels1))
print(len(_10x10_labels1))

#ASSOCIATED TARGET VALUES
_2x2_target= np.array(original_labels_2x2_8000)
_3x3_target=np.array(original_labels_3x3_4000)
_5x5_target=np.array(original_labels_5x5_4000)
_10x10_target= np.array(original_labels_10x10_4000)

print("Dimension of target value arrays (Effective Young´s Modulus, E11)")
print(len(_2x2_target))
print(len(_3x3_target))
print(len(_5x5_target))
print(len(_10x10_target))
# Out:
# Assemble Dataset
# Dimension of the input data (Images)
# (7772, 64, 64, 1)
# (3980, 64, 64, 1)
# (3854, 64, 64, 1)
# (3817, 64, 64, 1)
# Dimension of label arrays (Categories)
# 7772
# 3980
# 3854
# 3817
# Dimension of target value arrays (Effective Young´s Modulus, E11)
# 7772
# 3980
# 3854
# 3817

# %% [markdown]
# # Visualization of original images

# %%
ff='Palatino Linotype' 
plt.rcParams["font.family"] = ff
plt.rc('font', size=12)
plt.rcParams["figure.figsize"] = (10,3)
# %matplotlib notebook

f, axarr = plt.subplots(1,4)
axarr[0].imshow(_2x2_images[0,:,:,0],cmap= "gist_gray")
axarr[0].axis('off')
axarr[0].set_title("2\u03BCmx2\u03BCm")
axarr[1].imshow(_3x3_images[0,:,:,0],cmap= "gist_gray")
axarr[1].axis('off')
axarr[1].set_title("3\u03BCmx3\u03BCm")
axarr[2].imshow(_5x5_images[0,:,:,0],cmap= "gist_gray")
axarr[2].axis('off')
axarr[2].set_title("5\u03BCmx5\u03BCm")
axarr[3].imshow(_10x10_images[0,:,:,0],cmap= "gist_gray")
axarr[3].axis('off')
axarr[3].set_title("10\u03BCmx10\u03BCm")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.68">

# %% [markdown]
# # Implementation of a generative model: VAE or GAN (DCGAN, cDCGAN, WGAN, InfoGAN)

# %% [markdown]
# Links of interest (theory and code implementation examples)
#
# **VAEs**
#
# - https://towardsdatascience.com/understanding-variational-autoencoders-vaes-f70510919f73
# - https://becominghuman.ai/using-variational-autoencoder-vae-to-generate-new-images-14328877e88d
# - https://lilianweng.github.io/posts/2018-08-12-vae/
# - https://towardsdatascience.com/variational-autoencoders-as-generative-models-with-keras-e0c79415a7eb
#
# **GAN**
# - https://towardsdatascience.com/understanding-generative-adversarial-networks-gans-cd6e4651a29
# - https://machinelearningmastery.com/what-are-generative-adversarial-networks-gans/
#
# **DCGAN and cDCGAN**
# - https://machinelearningmastery.com/how-to-develop-a-conditional-generative-adversarial-network-from-scratch/
#
# **InfoGAN**
# - https://machinelearningmastery.com/how-to-develop-an-information-maximizing-generative-adversarial-network-infogan-in-keras/
# - https://towardsdatascience.com/build-infogan-from-scratch-f20ee85cba03
#
# **WGAN**
# - https://lilianweng.github.io/posts/2017-08-20-gan/
# - https://machinelearningmastery.com/how-to-code-a-wasserstein-generative-adversarial-network-wgan-from-scratch/
# - https://blog.paperspace.com/wgans/
